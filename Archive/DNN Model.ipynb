# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import backend as K
import gc

# %%
# DNN 1
dnn1 = build_dnn(X_train.shape[1], [128, 64], 0.2)
dnn1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32, verbose=0)
mae1 = dnn1.evaluate(X_test, y_test, verbose=0)[1]
results['DNN_1'] = 1 - mae1
K.clear_session()
gc.collect()

# %%
# DNN 2
dnn2 = build_dnn(X_train.shape[1], [256, 128], 0.3)
dnn2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=64, verbose=0)
mae2 = dnn2.evaluate(X_test, y_test, verbose=0)[1]
results['DNN_2'] = 1 - mae2
K.clear_session()
gc.collect()

# %%
# DNN 3
dnn3 = build_dnn(X_train.shape[1], [64, 64], 0.1)
dnn3.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=40, batch_size=16, verbose=0)
mae3 = dnn3.evaluate(X_test, y_test, verbose=0)[1]
results['DNN_3'] = 1 - mae3
K.clear_session()
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # DNN 3
# ----> 2 dnn3 = build_dnn(X_train.shape[1], [64, 64], 0.1)
#       3 dnn3.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=40, batch_size=16, verbose=0)
#       4 mae3 = dnn3.evaluate(X_test, y_test, verbose=0)[1]
#
# NameError: name 'build_dnn' is not defined

# %%
# Save results
pd.Series(results).to_csv('dnn_model_results.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Save results
# ----> 2 pd.Series(results).to_csv('dnn_model_results.csv')
#
# NameError: name 'pd' is not defined
