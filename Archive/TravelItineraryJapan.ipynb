# %%
# Creating Excel-style itinerary table for child-friendly Fukuoka trip April 10–15, 2025

import pandas as pd
import os

# Define itinerary data
data = [
    ["April 10 (Thu)", "7:00 PM", "Arrive at Fukuoka Airport"],
    ["April 10 (Thu)", "8:00 PM", "Transfer to hotel near Hakata Station"],
    ["April 10 (Thu)", "8:30 PM", "Dinner at Ichiran Ramen"],
    ["April 10 (Thu)", "9:30 PM", "Visit Don Quijote Nakasu"],
    ["April 10 (Thu)", "10:30 PM", "Rest at hotel"],
    
    ["April 11 (Fri)", "9:00 AM", "Breakfast"],
    ["April 11 (Fri)", "10:00 AM", "Maizuru Park & Fukuoka Castle Ruins"],
    ["April 11 (Fri)", "12:30 PM", "Picnic lunch or café"],
    ["April 11 (Fri)", "2:00 PM", "Ohori Park – swan boats & playground"],
    ["April 11 (Fri)", "4:00 PM", "Fukuoka Art Museum"],
    ["April 11 (Fri)", "6:00 PM", "Dinner in Tenjin"],
    ["April 11 (Fri)", "8:00 PM", "Optional Don Quijote Imaizumi"],
    
    ["April 12 (Sat)", "9:00 AM", "Train to Dazaifu"],
    ["April 12 (Sat)", "10:00 AM", "Dazaifu Tenmangu Shrine"],
    ["April 12 (Sat)", "11:30 AM", "Kyushu National Museum"],
    ["April 12 (Sat)", "1:00 PM", "Umegae mochi & lunch"],
    ["April 12 (Sat)", "2:30 PM", "Komyozenji Zen Garden"],
    ["April 12 (Sat)", "4:00 PM", "Return to Fukuoka"],
    ["April 12 (Sat)", "6:00 PM", "Dinner at Hakata Motsunabe Yamanaka"],
    
    ["April 13 (Sun)", "9:30 AM", "Momochi Seaside Park"],
    ["April 13 (Sun)", "10:30 AM", "Fukuoka Tower"],
    ["April 13 (Sun)", "12:00 PM", "Lunch at Marizon"],
    ["April 13 (Sun)", "2:00 PM", "Beach or Fukuoka City Museum"],
    ["April 13 (Sun)", "4:30 PM", "Tenjin Chikagai shopping"],
    ["April 13 (Sun)", "6:30 PM", "Dinner at Yatai stalls"],
    ["April 13 (Sun)", "8:30 PM", "Optional Don Quijote Nakasu"],
    
    ["April 14 (Mon)", "9:00 AM", "Yanagibashi Rengo Market"],
    ["April 14 (Mon)", "10:30 AM", "Kushida Shrine & Hakata Machiya Folk Museum"],
    ["April 14 (Mon)", "12:30 PM", "Lunch at Hakata Issou"],
    ["April 14 (Mon)", "2:00 PM", "TeamLab Forest Fukuoka"],
    ["April 14 (Mon)", "6:00 PM", "Dinner at Nikuya no Daidokoro Hakata"],
    ["April 14 (Mon)", "8:00 PM", "Final Donki run"],
    
    ["April 15 (Tue)", "9:00 AM", "Breakfast & pack up"],
    ["April 15 (Tue)", "10:00 AM", "Canal City Hakata shopping"],
    ["April 15 (Tue)", "12:00 PM", "Light lunch"],
    ["April 15 (Tue)", "1:30 PM", "Head to Fukuoka Airport"],
    ["April 15 (Tue)", "4:00 PM", "Departure"]
]

# Create DataFrame
df = pd.DataFrame(data, columns=["Date", "Time", "Activity"])

# Save to an 'outputs' folder next to this notebook (cross-platform)
output_dir = os.path.join(os.getcwd(), "outputs")
os.makedirs(output_dir, exist_ok=True)
output_path = os.path.join(output_dir, "fukuoka_child_friendly_itinerary.xlsx")

df.to_excel(output_path, index=False)

print("Itinerary Excel file created:", output_path)
# Out:
# Itinerary Excel file created: /Users/jaacabrera/Documents/Python Scripts/data_io/outputs/fukuoka_child_friendly_itinerary.xlsx
