# %%
import pandas as pd
import numpy as np

# Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# First, install Prophet (uncomment and run this cell first)
# !pip install prophet

# Prophet for forecasting
from prophet import Prophet
from prophet.plot import plot_cross_validation_metric
from prophet.diagnostics import performance_metrics
from prophet.diagnostics import cross_validation

# Evaluation metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Suppress warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, message="use_inf_as_na option is deprecated")

# Visualization settings
sns.set_theme(style="white", palette="pastel")

# Pandas display options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 4.4 MB/s  0:00:01m 4.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [prophet]━━━ 4/5 [prophet]]
# ...

# %%
df_train = pd.read_excel('walmart-sales-dataset-of-45stores result.xlsx')

# %%
df_train.head()
# Out:
#   Unnamed: 0   Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price          CPI  Unemployment
# 0      Count  6435.0  6.435000e+03    6435.00000  6435.000000  6435.000000  6435.000000   6435.000000
# 1    Minimum     1.0  2.099862e+05       0.00000    -2.060000     2.472000   126.064000      3.879000
# 2    Maximum    45.0  3.818686e+06       1.00000   100.140000     4.468000   227.232807     14.313000
# 3       Mean    23.0  1.046965e+06       0.06993    60.663782     3.358607   171.578394      7.999151
# 4     Median    23.0  9.607460e+05       0.00000    62.670000     3.445000   182.616521      7.874000

# %%
df_train.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price          CPI  Unemployment
# count    13.000000  1.300000e+01     13.000000    13.000000    13.000000    13.000000     13.000000
# mean    521.344606  2.450150e+10    496.087533   557.663409   497.068523   721.706324    500.751583
# std    1777.389562  8.833847e+10   1784.423072  1768.107302  1784.127261  1762.597876   1783.023337
# min      -1.201186  5.216739e-02      0.000000    -2.060000    -1.177395    -1.839316      1.187867
# 25%       1.000000  2.099862e+05      0.000000    18.444933     0.459020   126.064000      3.518944
# 50%      23.000000  5.643666e+05      0.065050    60.663782     3.358607   171.578394      7.874000
# 75%      34.000000  1.046965e+06      1.000000    74.940000     3.638000   212.743293      8.099000
# max    6435.000000  3.185097e+11   6435.000000  6435.000000  6435.000000  6435.000000   6435.000000

# %%
df_train.isnull().sum()
# Out:
# Unnamed: 0      0
# Store           0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
#df_train['total_price'] = df_train['total_price'].fillna(df_train['total_price'].median())

# %%
# Create a DataFrame with the columns and null counts you provided
import pandas as pd

# Create the DataFrame based on the null counts you provided
data = {
    'Unnamed: 0': [0],
    'Store': [0],
    'Weekly_Sales': [0],
    'Holiday_Flag': [0],
    'Temperature': [0],
    'Fuel_Price': [0],
    'CPI': [0],
    'Unemployment': [0]
}

df_train = pd.DataFrame(data)

# This is what your df_train.isnull().sum() would look like
null_counts = pd.Series({
    'Unnamed: 0': 0,
    'Store': 0,
    'Weekly_Sales': 0,
    'Holiday_Flag': 0,
    'Temperature': 0,
    'Fuel_Price': 0,
    'CPI': 0,
    'Unemployment': 0
})

print(null_counts)
# Out:
# Unnamed: 0      0
# Store           0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64
