# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set up output directory
output_dir = "./2026 Goal"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Monthly Snapshot Table
monthly_snapshot = pd.DataFrame({
    "Category": [
        "Fixed Costs", "Essentials", "Lifestyle", "Emergency Fund",
        "House Savings", "Investments", "Giving/Support", "Buffer/Misc"
    ],
    "Budget (₱)": [20000, 40000, 30000, 25000, 70000, 10000, 5000, 0],
    "Actual (₱)": [""] * 8,
    "Notes": [
        "", "", "", "Goal: ₱360K total", "Goal: ₱1M in 12 months",
        "Index fund", "Optional", "Fully allocated this month"
    ]
})

# Goals Tracker Table
monthly_goals = pd.DataFrame({
    "Goal": ["Emergency Fund", "House Downpayment", "Investments"],
    "Target (₱)": [360000, 1000000, 120000],
    "Saved (₱)": [60000, "", ""],
    "Remaining (₱)": [300000, 1000000, 120000],
    "% Complete": ["17%", "0%", "0%"]
})
